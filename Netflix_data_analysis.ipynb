# %%
pip install pandas numpy matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-07c73b5c-b347-48ef-b8aa-7800b954e4f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07c73b5c-b347-48ef-b8aa-7800b954e4f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("netflix_titles.csv.zip")

# %%
df.head()

df.tail()

df.shape

df.columns

df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.fillna("Unknown", inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %%
df['year_added'] = df['date_added'].dt.year

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df['type'].value_counts().plot(kind='bar')

plt.title("Movies vs TV Shows")

plt.show()

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# Unknown            831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
df['country'].value_counts().head(10).plot(kind='bar')

plt.title("Top Countries")

plt.show()

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# Unknown        4
# NC-17          3
# UR             3
# 66 min         1
# 74 min         1
# 84 min         1
# Name: count, dtype: int64

# %%
df['rating'].value_counts().plot(kind='bar')

plt.title("Ratings")

plt.show()

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Unknown                   2634
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Martin Scorsese             12
# Youssef Chahine             12
# Jay Chapman                 12
# Name: count, dtype: int64

# %%
movies = df[df['type']=="Movie"]

movies['release_year'].value_counts().sort_index().plot()

plt.title("Movies Released Per Year")

plt.show()

# %%
df['year_added'].value_counts().sort_index().plot()

plt.title("Netflix Content Added Every Year")

plt.show()

# %%
df['listed_in'].value_counts().head(10)
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            220
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: count, dtype: int64

# %%
movies.sort_values('duration',ascending=False).head()
# Out:
#      show_id   type                                 title      director  \
# 5794   s5795  Movie                 Louis C.K.: Hilarious    Louis C.K.
# 5541   s5542  Movie                       Louis C.K. 2017    Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store    Louis C.K.
# 6415   s6416  Movie                              Candyman  Bernard Rose
# 3411   s3412  Movie                              Up North    Tope Oshin
#
#                                                    cast  \
# 5794                                         Louis C.K.
# 5541                                         Louis C.K.
# 5813                                         Louis C.K.
# 6415  Virginia Madsen, Tony Todd, Xander Berkeley, K...
# 3411  Banky Wellington, Rahama Sadau, Kanayo O. Kana...
#
#                             country date_added  release_year  rating duration  \
# 5794                  United States 2016-09-16          2010  84 min  Unknown
# ...

# %%
movies.sort_values('release_year').head()
# Out:
#      show_id   type                                          title  \
# 7790   s7791  Movie                                 Prelude to War
# 8205   s8206  Movie                           The Battle of Midway
# 8660   s8661  Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740  Movie             Why We Fight: The Battle of Russia
# 8763   s8764  Movie                WWII: Report from the Aleutians
#
#                          director                       cast        country  \
# 7790                  Frank Capra                    Unknown  United States
# 8205                    John Ford  Henry Fonda, Jane Darwell  United States
# 8660                    John Ford                    Unknown  United States
# 8739  Frank Capra, Anatole Litvak                    Unknown  United States
# 8763                  John Huston                    Unknown  United States
#
#      date_added  release_year rating duration                      listed_in  \
# ...

# %%
movies.sort_values('release_year',ascending=False).head()
# Out:
#    show_id   type                           title  \
# 45     s46  Movie          My Heroes Were Cowboys
# 36     s37  Movie                  The Stronghold
# 35     s36  Movie  The Father Who Moves Mountains
# 30     s31  Movie                 Ankahi Kahaniya
# 64     s65  Movie                      Nightbooks
#
#                                              director  \
# 45                                        Tyler Greco
# 36                                     Cédric Jimenez
# 35                                       Daniel Sandu
# 30  Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket C...
# 64                                    David Yarovesky
#
#                                                  cast  country date_added  \
# 45                                            Unknown  Unknown 2021-09-16
# 36  Gilles Lellouche, Karim Leklou, François Civil...  Unknown 2021-09-17
# 35  Adrian Titieni, Elena Purea, Judith State, Val...  Unknown 2021-09-17
# ...

# %%
df.to_csv("cleaned_netflix.csv", index=False)

# %%
from google.colab import files

files.download("cleaned_netflix.csv")
